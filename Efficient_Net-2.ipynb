# %% [markdown]
# # Efficient_Net

# %% [markdown]
# THE FOLLOWING STEPS ARE INVOLVED IN THE ENTIRE PROCESS OF IMAGE CLASSIFICATION
#
# 1.IMPORTING LIBRARIES
#
# 2.IMAGE PROCESSING
#
# 3.MODEL CREATION
#
# 4.MODEL COMPILATION
#
# 5.MODEL TRAINING
#
# 6.MODEL EVALUATION
#
# 7.MODEL PREDICTION

# %% [markdown]
# STEP 1-importing essential libraries tensorflow is a deep learning framework suitable for applications involving neural networks.
#
# using tensorflow we can build,train,evaluate and predict our neural network.

# %%
#importing the essential libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
# Out:
# 2024-02-27 13:04:35.456590: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_set='archive-3/train'
val_set='archive-3/val'
test_set='archive-3/test'

# %% [markdown]
# STEP 2-image processing
# the imagedatagenerator is used to implement data augmentation. we can process the image as we want and create batches of image data.
#
# check this link for further details:- https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

# %%
train_datagen = image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)
validation_datagen= image.ImageDataGenerator(rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1)
test_datagen= image.ImageDataGenerator(rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1)

# %%
# image addressing
train_generator = train_datagen.flow_from_directory(
    train_set,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical')
validation_generator = validation_datagen.flow_from_directory(
    val_set,
    target_size = (224,224),
    batch_size = 16,
    shuffle=True,
    class_mode = 'categorical')
test_generator = test_datagen.flow_from_directory(
    test_set,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical')
# Out:
# Found 3200 images belonging to 4 classes.
# Found 2000 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.

# %%
train_generator.class_indices
# Out:
# {'0_normal': 0, '1_ulcerative_colitis': 1, '2_polyps': 2, '3_esophagitis': 3}

# %%
import matplotlib.pyplot as plt

# Set the number of images to display
num_images_to_display = 30

# Initialize a counter for displayed images
displayed_images = 0

# Set the figure size for larger images
plt.figure(figsize=(15, 15))

# Iterate through generator batches until reaching the desired number of displayed images
for batch_images, batch_labels in train_generator:
    batch_size = batch_images.shape[0]
    for i in range(batch_size):
        if displayed_images < num_images_to_display:
            plt.subplot(6, 5, displayed_images + 1)
            plt.imshow(batch_images[i].astype('uint8'))
            plt.title(f"Class: {batch_labels[i].argmax()}", fontsize=10)
            plt.axis("off")
            displayed_images += 1
        else:
            break

    if displayed_images >= num_images_to_display:
        break

# Adjust layout to prevent overlapping titles
plt.tight_layout()
plt.show()

# %% [markdown]
# STEP 3-model creation
# we are using the pretrained cnn meaning that the cnn is already trained on the imagenet dataset and has the weights stored in it. we are going to customise the model by adding additional layers of our choice(remember more layers can increase parameters leading to overfitting).
#
# we are using the MobileNetV2 model for this application. this model was developed by google in 2017 and is known for its light memory. this model is ideal for devices with less RAM and processing power like microcomputers and mobiles.
#
# input_shape=(224,224,3) => this is the input dimensions of the model. this is the parameter mentioned in the processing part. the 3 refers to the three channels R,G,B
#
# we are training it partially so as to reduce the traning time on the stake of accuracy. (it is better to train model fully for better results)

# %%
from tensorflow.keras import regularizers
from keras.regularizers import l2

base_model = tf.keras.applications.EfficientNetB2(weights='imagenet', input_shape=(224,224,3), include_top=False)

for layer in base_model.layers:
    layer.trainable=False
model = Sequential()
model.add(base_model)
#model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(GaussianNoise(0.35))
model.add(GlobalAveragePooling2D())
model.add(Dense(256,activation='relu'))
model.add(BatchNormalization())
model.add(GaussianNoise(0.35))
model.add(Dense(356,activation='relu'))
model.add(BatchNormalization())
model.add(GaussianNoise(0.35))
model.add(Dropout(0.2))
model.add(Dense(4, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb2 (Functional  (None, 7, 7, 1408)        7768569
#  )
#
#  gaussian_noise (GaussianNo  (None, 7, 7, 1408)        0
#  ise)
#
#  global_average_pooling2d (  (None, 1408)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               360704
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  gaussian_noise_1 (Gaussian  (None, 256)               0
#  Noise)
#
#  dense_1 (Dense)             (None, 356)               91492
#
#  batch_normalization_1 (Bat  (None, 356)               1424
#  chNormalization)
#
#  gaussian_noise_2 (Gaussian  (None, 356)               0
#  Noise)
#
#  dropout (Dropout)           (None, 356)               0
#
#  dense_2 (Dense)             (None, 4)                 1428
#
# =================================================================
# Total params: 8224641 (31.37 MB)
# Trainable params: 454848 (1.74 MB)
# Non-trainable params: 7769793 (29.64 MB)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy','Precision','Recall','AUC'])

# %%
history = model.fit(
    train_generator,
    epochs=20,
    validation_data=validation_generator,
    steps_per_epoch=len(train_generator),
    validation_steps=len(validation_generator)
)
# Out:
# Epoch 1/20
# 200/200 [==============================] - 511s 3s/step - loss: 0.2997 - accuracy: 0.8959 - precision: 0.9036 - recall: 0.8903 - auc: 0.9834 - val_loss: 0.2253 - val_accuracy: 0.9165 - val_precision: 0.9222 - val_recall: 0.9125 - val_auc: 0.9905
# Epoch 2/20
# 200/200 [==============================] - 472s 2s/step - loss: 0.1702 - accuracy: 0.9431 - precision: 0.9471 - recall: 0.9406 - auc: 0.9935 - val_loss: 0.3292 - val_accuracy: 0.8925 - val_precision: 0.8958 - val_recall: 0.8895 - val_auc: 0.9821
# Epoch 3/20
# 200/200 [==============================] - 570s 3s/step - loss: 0.1396 - accuracy: 0.9491 - precision: 0.9510 - recall: 0.9469 - auc: 0.9952 - val_loss: 0.2554 - val_accuracy: 0.9250 - val_precision: 0.9257 - val_recall: 0.9220 - val_auc: 0.9882
# Epoch 4/20
# 200/200 [==============================] - 586s 3s/step - loss: 0.1152 - accuracy: 0.9600 - precision: 0.9606 - recall: 0.9588 - auc: 0.9966 - val_loss: 0.2481 - val_accuracy: 0.9160 - val_precision: 0.9190 - val_recall: 0.9130 - val_auc: 0.9887
# Epoch 5/20
# 200/200 [==============================] - 627s 3s/step - loss: 0.0942 - accuracy: 0.9678 - precision: 0.9683 - recall: 0.9650 - auc: 0.9970 - val_loss: 0.1525 - val_accuracy: 0.9500 - val_precision: 0.9514 - val_recall: 0.9500 - val_auc: 0.9947
# Epoch 6/20
# 200/200 [==============================] - 1471s 7s/step - loss: 0.1077 - accuracy: 0.9641 - precision: 0.9649 - recall: 0.9628 - auc: 0.9959 - val_loss: 0.1808 - val_accuracy: 0.9340 - val_precision: 0.9377 - val_recall: 0.9330 - val_auc: 0.9933
# Epoch 7/20
# 200/200 [==============================] - 482s 2s/step - loss: 0.0936 - accuracy: 0.9678 - precision: 0.9680 - recall: 0.9656 - auc: 0.9975 - val_loss: 0.1469 - val_accuracy: 0.9495 - val_precision: 0.9504 - val_recall: 0.9485 - val_auc: 0.9947
# Epoch 8/20
# 200/200 [==============================] - 490s 2s/step - loss: 0.0743 - accuracy: 0.9756 - precision: 0.9759 - recall: 0.9756 - auc: 0.9977 - val_loss: 0.1244 - val_accuracy: 0.9565 - val_precision: 0.9565 - val_recall: 0.9560 - val_auc: 0.9961
# Epoch 9/20
# 200/200 [==============================] - 480s 2s/step - loss: 0.0872 - accuracy: 0.9719 - precision: 0.9734 - recall: 0.9716 - auc: 0.9971 - val_loss: 0.2049 - val_accuracy: 0.9255 - val_precision: 0.9254 - val_recall: 0.9240 - val_auc: 0.9924
# Epoch 10/20
# 200/200 [==============================] - 533s 3s/step - loss: 0.0769 - accuracy: 0.9744 - precision: 0.9750 - recall: 0.9741 - auc: 0.9976 - val_loss: 0.2223 - val_accuracy: 0.9330 - val_precision: 0.9343 - val_recall: 0.9315 - val_auc: 0.9901
# Epoch 11/20
# 200/200 [==============================] - 486s 2s/step - loss: 0.0612 - accuracy: 0.9762 - precision: 0.9769 - recall: 0.9759 - auc: 0.9989 - val_loss: 0.1552 - val_accuracy: 0.9475 - val_precision: 0.9493 - val_recall: 0.9465 - val_auc: 0.9947
# Epoch 12/20
# 200/200 [==============================] - 12110s 61s/step - loss: 0.0500 - accuracy: 0.9803 - precision: 0.9812 - recall: 0.9803 - auc: 0.9993 - val_loss: 0.1816 - val_accuracy: 0.9445 - val_precision: 0.9449 - val_recall: 0.9430 - val_auc: 0.9920
# Epoch 13/20
# 200/200 [==============================] - 610s 3s/step - loss: 0.0815 - accuracy: 0.9731 - precision: 0.9740 - recall: 0.9728 - auc: 0.9978 - val_loss: 0.1854 - val_accuracy: 0.9415 - val_precision: 0.9453 - val_recall: 0.9410 - val_auc: 0.9919
# Epoch 14/20
# 200/200 [==============================] - 543s 3s/step - loss: 0.0608 - accuracy: 0.9797 - precision: 0.9803 - recall: 0.9787 - auc: 0.9983 - val_loss: 0.1476 - val_accuracy: 0.9530 - val_precision: 0.9535 - val_recall: 0.9530 - val_auc: 0.9950
# Epoch 15/20
# 200/200 [==============================] - 549s 3s/step - loss: 0.0705 - accuracy: 0.9731 - precision: 0.9737 - recall: 0.9731 - auc: 0.9984 - val_loss: 0.1973 - val_accuracy: 0.9285 - val_precision: 0.9299 - val_recall: 0.9285 - val_auc: 0.9925
# Epoch 16/20
# 200/200 [==============================] - 504s 3s/step - loss: 0.0642 - accuracy: 0.9794 - precision: 0.9797 - recall: 0.9787 - auc: 0.9984 - val_loss: 0.1153 - val_accuracy: 0.9565 - val_precision: 0.9569 - val_recall: 0.9555 - val_auc: 0.9967
# Epoch 17/20
# 200/200 [==============================] - 461s 2s/step - loss: 0.0456 - accuracy: 0.9850 - precision: 0.9853 - recall: 0.9847 - auc: 0.9991 - val_loss: 0.1973 - val_accuracy: 0.9360 - val_precision: 0.9369 - val_recall: 0.9350 - val_auc: 0.9919
# Epoch 18/20
# 200/200 [==============================] - 526s 3s/step - loss: 0.0708 - accuracy: 0.9731 - precision: 0.9737 - recall: 0.9725 - auc: 0.9981 - val_loss: 0.1639 - val_accuracy: 0.9440 - val_precision: 0.9449 - val_recall: 0.9430 - val_auc: 0.9935
# Epoch 19/20
# 200/200 [==============================] - 527s 3s/step - loss: 0.0530 - accuracy: 0.9825 - precision: 0.9828 - recall: 0.9825 - auc: 0.9991 - val_loss: 0.1908 - val_accuracy: 0.9350 - val_precision: 0.9372 - val_recall: 0.9330 - val_auc: 0.9933
# Epoch 20/20
# 200/200 [==============================] - 541s 3s/step - loss: 0.0667 - accuracy: 0.9772 - precision: 0.9775 - recall: 0.9769 - auc: 0.9981 - val_loss: 0.1179 - val_accuracy: 0.9575 - val_precision: 0.9575 - val_recall: 0.9570 - val_auc: 0.9965

# %% [markdown]
# Model evaluation
# the trained model is evaluated on training, validation and test dataset

# %%
model.evaluate(train_generator)
# Out:
# 200/200 [==============================] - 316s 2s/step - loss: 0.0141 - accuracy: 0.9953 - precision: 0.9953 - recall: 0.9953 - auc: 1.0000
# [0.01413565780967474,
#  0.995312511920929,
#  0.995312511920929,
#  0.995312511920929,
#  0.9999683499336243]

# %%
model.evaluate(test_generator)
# Out:
# 50/50 [==============================] - 71s 1s/step - loss: 0.0944 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9982
# [0.09442246705293655,
#  0.9674999713897705,
#  0.9674999713897705,
#  0.9674999713897705,
#  0.9982485175132751]

# %% [markdown]
# Performance

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.plot( np.argmin(history.history["val_loss"]), np.min(history.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %%
from keras.preprocessing import image
img = image.load_img('/content/drive/MyDrive/Gastrovision-2/Esophagitis/0ad8f762-0fa6-46fd-b98d-a1b401f5ca5c.jpg',target_size=(224,224))
imag = image.img_to_array(img)
imaga = np.expand_dims(imag,axis=0)
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,-1)
if a==0:
    op="Normal"
elif a==1:
    op="Ulcerative colitis"
elif a==2:
    op="Polyp"
else:
    op="Esophagitis"

plt.imshow(img)
print("THE UPLOADED IMAGE SEEMS TO BE: "+str(op))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 from keras.preprocessing import image
# ----> 2 img = image.load_img('/content/drive/MyDrive/Gastrovision-2/Esophagitis/0ad8f762-0fa6-46fd-b98d-a1b401f5ca5c.jpg',target_size=(224,224))
#       3 imag = image.img_to_array(img)
#       4 imaga = np.expand_dims(imag,axis=0)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/src/utils/image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Gastrovision-2/Esophagitis/0ad8f762-0fa6-46fd-b98d-a1b401f5ca5c.jpg'

# %%
from keras.preprocessing import image
img = image.load_img('/content/drive/MyDrive/Gastrovision-2/Colorectal cancer/02c18e5f-6c77-4104-bff2-238f587b1c28.jpg',target_size=(224,224))
imag = image.img_to_array(img)
imaga = np.expand_dims(imag,axis=0)
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,-1)
if a==0:
    op="Normal"
elif a==1:
    op="Ulcerative colitis"
elif a==2:
    op="Polyp"
else:
    op="Esophagitis"

plt.imshow(img)
print("THE UPLOADED IMAGE SEEMS TO BE: "+str(op))

# %%
from keras.preprocessing import image
img = image.load_img('/content/drive/MyDrive/archive-3/test/0_normal/test_normal_ (112).jpg',target_size=(224,224))
imag = image.img_to_array(img)
imaga = np.expand_dims(imag,axis=0)
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,-1)
if a==0:
    op="Normal"
elif a==1:
    op="Ulcerative colitis"
elif a==2:
    op="Polyp"
else:
    op="Esophagitis"

plt.imshow(img)
print("THE UPLOADED IMAGE SEEMS TO BE: "+str(op))

# %%
model.save('modelfinal.h5')
# Out:
# /Users/dharmik/opt/anaconda3/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
